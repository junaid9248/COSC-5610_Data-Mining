# %% [markdown]
# # Assignment 1 : Data Frame Operations with Pandas

# %% [markdown]
# Task 1: Import the Necessary Libraries

# %%
import pandas as pd

# %% [markdown]
# Task 2: Loading data into dataframes

# %%
employee_df = pd.read_csv('C:/Users/ther3/Marquette/Spring 2025/COSC 5610 - Data Mining/codes/Assignment 1/EMPLOYEE.csv')
department_df = pd.read_csv('C:/Users/ther3/Marquette/Spring 2025/COSC 5610 - Data Mining/codes/Assignment 1/DEPARTMENT.csv')

# %% [markdown]
# Task 3: Inspect the data

# %%
employee_df.head(5)
# Out:
#       FNAME    LNAME        SSN      BDATE                     ADDRESS  \
# 0     James     Borg  888665555  10-Nov-27      450 Stone, Houston, TX
# 1  Jennifer  Wallace  987654321  20-Jun-31     291 Berry, Bellaire, TX
# 2    Alicia   Zelaya  999887777  19-Jul-58     3321 Castle, Spring, TX
# 3     Ahmad   Jabbar  987987987  29-Mar-59     980 Dallas, Houston, TX
# 4     Joyce  English  453453453  31-Jul-62  5631 Rice Oak, Houston, TX
#
#     SALARY     SUPERSSN  DNO
# 0  55000.0          NaN    1
# 1  43000.0  888665555.0    4
# 2  25000.0  987654321.0    4
# 3  25000.0  987654321.0    4
# 4  25000.0  333445555.0    5

# %%
department_df.head(5)
# Out:
#             DNAME  DNUMBER     MGRSSN MGRSTARTDATE
# 0    Headquarters        1  888665555    19-JUN-71
# 1  Administration        4  987654321    01-JAN-85
# 2        Research        5  333445555    22-MAY-78
# 3        Software        6  111111100    15-MAY-99
# 4        Hardware        7  444444400    15-MAY-98

# %%
employee_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   FNAME     40 non-null     object
#  1   LNAME     40 non-null     object
#  2   SSN       40 non-null     int64
#  3   BDATE     40 non-null     object
#  4   ADDRESS   40 non-null     object
#  5   SALARY    37 non-null     float64
#  6   SUPERSSN  33 non-null     float64
#  7   DNO       40 non-null     int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 2.6+ KB

# %%
department_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   DNAME         6 non-null      object
#  1   DNUMBER       6 non-null      int64
#  2   MGRSSN        6 non-null      int64
#  3   MGRSTARTDATE  6 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 324.0+ bytes

# %% [markdown]
# Task 4: Data Cleaning

# %%
employee_null = employee_df.isnull()
employee_null
# Out:
#     FNAME  LNAME    SSN  BDATE  ADDRESS  SALARY  SUPERSSN    DNO
# 0   False  False  False  False    False   False      True  False
# 1   False  False  False  False    False   False     False  False
# 2   False  False  False  False    False   False     False  False
# 3   False  False  False  False    False   False     False  False
# 4   False  False  False  False    False   False     False  False
# 5   False  False  False  False    False   False     False  False
# 6   False  False  False  False    False   False     False  False
# 7   False  False  False  False    False   False     False  False
# 8   False  False  False  False    False   False      True  False
# 9   False  False  False  False    False   False     False  False
# 10  False  False  False  False    False   False     False  False
# 11  False  False  False  False    False   False     False  False
# 12  False  False  False  False    False   False     False  False
# ...

# %%
columns = employee_null.keys().tolist()
breaker = '-'*50
for index in range(0, len(columns)-1):
    null_value_index = employee_null.loc[employee_null[columns[index]] == True]
    print(f"For the {columns[index]} column: \n")
    print(null_value_index)
    print(f'{breaker} \n')
# Out:
# For the FNAME column:
#
# Empty DataFrame
# Columns: [FNAME, LNAME, SSN, BDATE, ADDRESS, SALARY, SUPERSSN, DNO]
# Index: []
# --------------------------------------------------
#
# For the LNAME column:
#
# Empty DataFrame
# Columns: [FNAME, LNAME, SSN, BDATE, ADDRESS, SALARY, SUPERSSN, DNO]
# Index: []
# --------------------------------------------------
#
# For the SSN column:
#
# Empty DataFrame
# Columns: [FNAME, LNAME, SSN, BDATE, ADDRESS, SALARY, SUPERSSN, DNO]
# Index: []
# --------------------------------------------------
#
# For the BDATE column:
#
# Empty DataFrame
# Columns: [FNAME, LNAME, SSN, BDATE, ADDRESS, SALARY, SUPERSSN, DNO]
# Index: []
# --------------------------------------------------
#
# For the ADDRESS column:
#
# Empty DataFrame
# Columns: [FNAME, LNAME, SSN, BDATE, ADDRESS, SALARY, SUPERSSN, DNO]
# Index: []
# --------------------------------------------------
#
# For the SALARY column:
#
#     FNAME  LNAME    SSN  BDATE  ADDRESS  SALARY  SUPERSSN    DNO
# ...

# %%
department_null = department_df.isnull()
department_null
# Out:
#    DNAME  DNUMBER  MGRSSN  MGRSTARTDATE
# 0  False    False   False         False
# 1  False    False   False         False
# 2  False    False   False         False
# 3  False    False   False         False
# 4  False    False   False         False
# 5  False    False   False         False

# %%
employee_df['SALARY'].fillna(employee_df['SALARY'].mean(), inplace=True)
# Out:
# C:\Users\ther3\AppData\Local\Temp\ipykernel_25084\2571161427.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   employee_df['SALARY'].fillna(employee_df['SALARY'].mean(), inplace=True)

# %% [markdown]
# Task 5: Data Manipulation

# %%
employees = employee_df[employee_df['SALARY'] > 40000]
print(type(employees))
employees= pd.DataFrame({
    'First Name': employees["FNAME"],
    'Last Name': employees["LNAME"],
    'SSN' :employees['SSN']
})

employees
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    First Name Last Name        SSN
# 0       James      Borg  888665555
# 1    Jennifer   Wallace  987654321
# 8       Jared     James  111111100
# 9        Brad    Knight  111111103
# 10       Jeff     Chase  333333301
# 11        Jon     Jones  111111101
# 13       John     James  555555500
# 14    Nandita      Ball  555555501
# 15        Kim     Grace  333333300
# 16        Sam   Snedden  444444403
# 17       Alec      Best  444444402
# 18     Bonnie      Bays  444444401
# 19      Jenny       Vos  222222204
# 20        Tom     Brand  222222203
# 21       Andy      Vile  222222202
# 22       Josh      Zell  222222201
# 23       Evan    Wallis  222222200
# 24       Alex     Freed  444444400
# 25      Chris    Carter  222222205
# 26        Bob    Bender  666666600
# 28       Kate      King  666666602
# 29       Lyle    Leslie  666666603
# 39        Ray      King  666666606

# %%
employees1 = employee_df[employee_df['SUPERSSN'] == 666666602]

employees1 = pd.DataFrame({
    'First Name': employees1["FNAME"],
    'Last Name': employees1["LNAME"],
    'SSN': employees1['SSN'],
 
})

employees1
# Out:
#    First Name Last Name        SSN
# 33     Gerald     Small  666666607
# 34     Arnold      Head  666666608
# 35      Helga    Pataki  666666609

# %%
employees1 = employee_df[employee_df['SUPERSSN'] == 666666602]
employees1[['FNAME', 'LNAME']]
# Out:
#      FNAME   LNAME
# 33  Gerald   Small
# 34  Arnold    Head
# 35   Helga  Pataki

# %% [markdown]
# Task 6: Merge Data

# %%
department_df.rename(columns={'DNUMBER': 'DNO'}, inplace=True)

# %%
employee_detailed = pd.merge(employee_df, department_df, on='DNO')

employee_detailed.head(10)
# Out:
#       FNAME    LNAME        SSN      BDATE                     ADDRESS  \
# 0     James     Borg  888665555  10-Nov-27      450 Stone, Houston, TX
# 1  Jennifer  Wallace  987654321  20-Jun-31     291 Berry, Bellaire, TX
# 2    Alicia   Zelaya  999887777  19-Jul-58     3321 Castle, Spring, TX
# 3     Ahmad   Jabbar  987987987  29-Mar-59     980 Dallas, Houston, TX
# 4     Joyce  English  453453453  31-Jul-62  5631 Rice Oak, Houston, TX
# 5  Franklin     Wong  333445555   8-Dec-45       638 Voss, Houston, TX
# 6      John    Smith  123456789   9-Jan-55    731 Fondren, Houston, TX
# 7    Ramesh  Narayan  666884444  15-Sep-52    971 Fire Oak, Humble, TX
# 8     Jared    James  111111100  10-Oct-66  123 Peachtree, Atlanta, GA
# 9      Brad   Knight  111111103  13-Feb-68   176 Main St., Atlanta, GA
#
#     SALARY     SUPERSSN  DNO           DNAME     MGRSSN MGRSTARTDATE
# 0  55000.0          NaN    1    Headquarters  888665555    19-JUN-71
# ...

# %%
research_employees = employee_detailed[employee_detailed['DNAME'] == 'Research']
research_employees = pd.DataFrame({
    'FIRST NAME': research_employees['FNAME'],
    'LAST NAME': research_employees['LNAME'],
    'EMPLOYEE SSN': research_employees['SSN']
})
research_employees
# Out:
#   FIRST NAME LAST NAME  EMPLOYEE SSN
# 4      Joyce   English     453453453
# 5   Franklin      Wong     333445555
# 6       John     Smith     123456789
# 7     Ramesh   Narayan     666884444

# %%
employee_detailed_null= pd.isnull(employee_detailed)
employee_detailed_null
# Out:
#     FNAME  LNAME    SSN  BDATE  ADDRESS  SALARY  SUPERSSN    DNO  DNAME  \
# 0   False  False  False  False    False   False      True  False  False
# 1   False  False  False  False    False   False     False  False  False
# 2   False  False  False  False    False   False     False  False  False
# 3   False  False  False  False    False   False     False  False  False
# 4   False  False  False  False    False   False     False  False  False
# 5   False  False  False  False    False   False     False  False  False
# 6   False  False  False  False    False   False     False  False  False
# 7   False  False  False  False    False   False     False  False  False
# 8   False  False  False  False    False   False      True  False  False
# 9   False  False  False  False    False   False     False  False  False
# 10  False  False  False  False    False   False     False  False  False
# 11  False  False  False  False    False   False     False  False  False
# ...

# %%
employee_detailed['SUPERSSN'].fillna(employee_detailed['MGRSSN'], inplace=True)
employee_detailed
# Out:
# C:\Users\ther3\AppData\Local\Temp\ipykernel_25084\2849336823.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   employee_detailed['SUPERSSN'].fillna(employee_detailed['MGRSSN'], inplace=True)
#        FNAME    LNAME        SSN      BDATE                           ADDRESS  \
# 0      James     Borg  888665555  10-Nov-27            450 Stone, Houston, TX
# 1   Jennifer  Wallace  987654321  20-Jun-31           291 Berry, Bellaire, TX
# 2     Alicia   Zelaya  999887777  19-Jul-58           3321 Castle, Spring, TX
# ...

# %%
employee_detailed.notnull()
# Out:
#     FNAME  LNAME   SSN  BDATE  ADDRESS  SALARY  SUPERSSN   DNO  DNAME  MGRSSN  \
# 0    True   True  True   True     True    True      True  True   True    True
# 1    True   True  True   True     True    True      True  True   True    True
# 2    True   True  True   True     True    True      True  True   True    True
# 3    True   True  True   True     True    True      True  True   True    True
# 4    True   True  True   True     True    True      True  True   True    True
# 5    True   True  True   True     True    True      True  True   True    True
# 6    True   True  True   True     True    True      True  True   True    True
# 7    True   True  True   True     True    True      True  True   True    True
# 8    True   True  True   True     True    True      True  True   True    True
# 9    True   True  True   True     True    True      True  True   True    True
# 10   True   True  True   True     True    True      True  True   True    True
# ...
